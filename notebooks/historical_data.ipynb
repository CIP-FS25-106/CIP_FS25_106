# %%
import pandas as pd

# %%
hist_data = pd.read_csv("C:/Users/rogej/Downloads/historical_data_20250404_141651/historical_data_20250404_141651.csv")
hist_data_new = pd.read_csv("C:/Users/rogej/Downloads/filtered_data_20250402_085117/filtered_data_20250402_085117.csv")

# %%
hist_data.head()
# Out:
#      ride_day            ride_description train_operator product_id line_text  \
# 0  2025-01-01    ch:1:sjyid:100001:10-001            SBB        Zug        EC
# 1  2025-01-01  ch:1:sjyid:100001:1007-001            SBB        Zug        IC
# 2  2025-01-01  ch:1:sjyid:100001:1009-001            SBB        Zug        IC
# 3  2025-01-01  ch:1:sjyid:100001:1011-001            SBB        Zug        IC
# 4  2025-01-01    ch:1:sjyid:100001:12-001            SBB        Zug        EC
#
#   train_category  extra_train  cancelled station_name scheduled_arrival  \
# 0             EC        False      False    Zürich HB  01.01.2025 10:27
# 1             IC        False      False    Zürich HB  01.01.2025 06:23
# 2             IC        False      False    Zürich HB  01.01.2025 07:23
# 3             IC        False      False    Zürich HB  01.01.2025 08:23
# 4             EC        False      False    Zürich HB  01.01.2025 11:27
#
#      arrival_prognosis arrival_prognosis_status  nostopping  \
# ...

# %%
hist_data_new.head()
# Out:
#   BETRIEBSTAG FAHRT_BEZEICHNER BETREIBER_ABK PRODUKT_ID LINIEN_TEXT  \
# 0  2022-01-01   85:11:1007:001           SBB        Zug         IC4
# 1  2022-01-01   85:11:1009:001           SBB        Zug         IC4
# 2  2022-01-01   85:11:1011:001           SBB        Zug         IC4
# 3  2022-01-01   85:11:1041:001           SBB        Zug          RE
# 4  2022-01-01   85:11:1187:002           SBB        Zug          EC
#
#   VERKEHRSMITTEL_TEXT  ZUSATZFAHRT_TF  FAELLT_AUS_TF HALTESTELLEN_NAME  \
# 0                  IC           False          False         Zürich HB
# 1                  IC           False          False         Zürich HB
# 2                  IC           False          False         Zürich HB
# 3                  RE           False          False         Zürich HB
# 4                  EC           False           True         Zürich HB
#
#        ANKUNFTSZEIT          AN_PROGNOSE AN_PROGNOSE_STATUS  DURCHFAHRT_TF  \
# ...

# %%
hist_data['DELAY'].describe()
# Out:
# count    198920.000000
# mean          0.564608
# std          30.829953
# min       -1439.000000
# 25%          -0.250000
# 50%           0.366667
# 75%           1.116667
# max        1439.983333
# Name: DELAY, dtype: float64

# %%
hist_data.tail()
# Out:
#         BETRIEBSTAG FAHRT_BEZEICHNER BETREIBER_ID BETREIBER_ABK  \
# 1501826  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501827  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501828  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501829  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501830  01.01.2024      85:97:9:000        85:97        TRAVYS
#
#                                       BETREIBER_NAME PRODUKT_ID LINIEN_ID  \
# 1501826  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501827  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501828  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501829  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501830  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
#
#         LINIEN_TEXT UMLAUF_ID VERKEHRSMITTEL_TEXT  ...  FAELLT_AUS_TF  \
# ...

# %%
new = pd.read_csv("C:/Users/rogej/Downloads/ist-daten-2025-01/2025-01-01_istdaten.csv", sep=";")
# Out:
# C:\Users\rogej\AppData\Local\Temp\ipykernel_41996\568718492.py:1: DtypeWarning: Columns (6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   new = pd.read_csv("C:/Users/rogej/Downloads/ist-daten-2025-01/2025-01-01_istdaten.csv", sep=";")

# %%
new.head()
# Out:
#   BETRIEBSTAG     FAHRT_BEZEICHNER BETREIBER_ID BETREIBER_ABK  \
# 0  01.01.2025  80:800631:17238:000    80:800631            DB
# 1  01.01.2025  80:800631:17239:000    80:800631            DB
# 2  01.01.2025  80:800631:17241:000    80:800631            DB
# 3  01.01.2025  80:800631:17243:000    80:800631            DB
# 4  01.01.2025  80:800631:17244:000    80:800631            DB
#
#                   BETREIBER_NAME PRODUKT_ID LINIEN_ID LINIEN_TEXT UMLAUF_ID  \
# 0  DB Regio AG Baden-Württemberg        Zug     17238          RB       NaN
# 1  DB Regio AG Baden-Württemberg        Zug     17239          RB       NaN
# 2  DB Regio AG Baden-Württemberg        Zug     17241          RB       NaN
# 3  DB Regio AG Baden-Württemberg        Zug     17243          RB       NaN
# 4  DB Regio AG Baden-Württemberg        Zug     17244          RB       NaN
#
#   VERKEHRSMITTEL_TEXT  ...  FAELLT_AUS_TF    BPUIC  HALTESTELLEN_NAME  \
# ...

# %%
new["AN_PROGNOSE_STATUS"]
# Out:
# 0          PROGNOSE
# 1               NaN
# 2               NaN
# 3               NaN
# 4          PROGNOSE
#              ...
# 1614505        REAL
# 1614506        REAL
# 1614507        REAL
# 1614508        REAL
# 1614509        REAL
# Name: AN_PROGNOSE_STATUS, Length: 1614510, dtype: object

# %%
column_names = new.columns.tolist()
print(f"column names: {column_names} and number of columns: {len(column_names)}")
# Out:
# column names: ['BETRIEBSTAG', 'FAHRT_BEZEICHNER', 'BETREIBER_ID', 'BETREIBER_ABK', 'BETREIBER_NAME', 'PRODUKT_ID', 'LINIEN_ID', 'LINIEN_TEXT', 'UMLAUF_ID', 'VERKEHRSMITTEL_TEXT', 'ZUSATZFAHRT_TF', 'FAELLT_AUS_TF', 'BPUIC', 'HALTESTELLEN_NAME', 'ANKUNFTSZEIT', 'AN_PROGNOSE', 'AN_PROGNOSE_STATUS', 'ABFAHRTSZEIT', 'AB_PROGNOSE', 'AB_PROGNOSE_STATUS', 'DURCHFAHRT_TF'] and number of columns: 21

# %%
luzern_station_board = pd.read_csv("C:/Users/rogej/Documents/web_applications/CIP_FS25_106/data/raw/2025-01/Luzern_2025-01-01.csv")
luzern_station_board.columns = luzern_station_board.columns.str.lower()

# %%
luzern_station_board.head()
# Out:
#   collection_date collection_time  station_id station_name train_category  \
# 0      2025-04-06        13:13:50     8505000       Luzern             RE
# 1      2025-04-06        13:13:50     8505000       Luzern              S
# 2      2025-04-06        13:13:50     8505000       Luzern              S
# 3      2025-04-06        13:13:50     8505000       Luzern              S
# 4      2025-04-06        13:13:50     8505000       Luzern              S
#
#   train_number train_operator        train_to departure_date departure_time  \
# 0           24            SBB           Olten     2025-01-01       00:05:00
# 1            3            SBB         Brunnen     2025-01-01       00:06:00
# 2            9            SBB  Beinwil am See     2025-01-01       00:10:00
# 3            5             ZB          Giswil     2025-01-01       00:12:00
# 4            6        BLS-bls    Langnau i.E.     2025-01-01       00:16:00
#
# ...

# %%
luzern_station_board['delay'].unique()
# Out:
# array([nan])

# %%
print(list(luzern_station_board.columns))
# Out:
# ['collection_date,collection_time,station_id,station_name,train_category,train_number,train_operator,train_to,departure_date,departure_time,arrival_date,arrival_time,departure_timestamp,arrival_timestamp,delay,platform,prognosis_departure,prognosis_arrival,prognosis_platform,capacity1st,capacity2nd,board_type']
