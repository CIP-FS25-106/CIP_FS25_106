# %%
import pandas as pd

# %%
hist_data = pd.read_csv('../data/raw/historical_data/ist-daten-2024-01/2024-01-01_istdaten.csv', sep=';')
# Out:
# C:\Users\rogej\AppData\Local\Temp\ipykernel_4720\4093414379.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist_data = pd.read_csv('../data/raw/historical_data/ist-daten-2024-01/2024-01-01_istdaten.csv', sep=';')

# %%
hist_data[100:150]
# Out:
#     BETRIEBSTAG     FAHRT_BEZEICHNER BETREIBER_ID BETREIBER_ABK  \
# 100  01.01.2024  80:8006C4:17139:000    80:8006C4            DB
# 101  01.01.2024  80:8006C4:17141:000    80:8006C4            DB
# 102  01.01.2024  80:8006C4:17150:000    80:8006C4            DB
# 103  01.01.2024  80:8006C4:17155:000    80:8006C4            DB
# 104  01.01.2024  80:8006C4:17158:000    80:8006C4            DB
# 105  01.01.2024  80:8006C4:17159:000    80:8006C4            DB
# 106  01.01.2024  80:8006C4:17168:000    80:8006C4            DB
# 107  01.01.2024  80:8006C4:17169:000    80:8006C4            DB
# 108  01.01.2024  80:8006C4:17171:000    80:8006C4            DB
# 109  01.01.2024  80:8006C4:17172:000    80:8006C4            DB
# 110  01.01.2024  80:8006C4:17173:000    80:8006C4            DB
# 111  01.01.2024  80:8006C4:17174:000    80:8006C4            DB
# 112  01.01.2024  80:8006C4:17175:000    80:8006C4            DB
# 113  01.01.2024  80:8006C4:17176:000    80:8006C4            DB
# ...

# %%
hist_data.tail()
# Out:
#         BETRIEBSTAG FAHRT_BEZEICHNER BETREIBER_ID BETREIBER_ABK  \
# 1501826  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501827  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501828  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501829  01.01.2024      85:97:9:000        85:97        TRAVYS
# 1501830  01.01.2024      85:97:9:000        85:97        TRAVYS
#
#                                       BETREIBER_NAME PRODUKT_ID LINIEN_ID  \
# 1501826  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501827  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501828  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501829  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
# 1501830  Transports Vallée de Joux-Yverdon-Ste-Croix        Zug         9
#
#         LINIEN_TEXT UMLAUF_ID VERKEHRSMITTEL_TEXT  ...  FAELLT_AUS_TF  \
# ...
